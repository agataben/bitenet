# %%
from google.colab import drive

drive.mount('/content/drive')
# %cd /content/drive/MyDrive
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive

# %%
import os

repo_path = '/content/drive/MyDrive/bitenet'
if os.path.isdir(repo_path):
    # %cd /content/drive/MyDrive/bitenet
    # !git pull origin fix/colab_notebook
else:
    # !git clone https://github.com/agataben/bitenet.git
    # %cd bitenet
    # !git checkout fix/colab_notebook
# Out:
# Cloning into 'bitenet'...
# remote: Enumerating objects: 41448, done.
# remote: Counting objects: 100% (162/162), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 41448 (delta 133), reused 144 (delta 122), pack-reused 41286 (from 2)
# Receiving objects: 100% (41448/41448), 1.86 GiB | 12.14 MiB/s, done.
# Resolving deltas: 100% (242/242), done.
# /content/drive/MyDrive/bitenet
# Updating files: 100% (41021/41021), done.
# Branch 'fix/colab_notebook' set up to track remote branch 'fix/colab_notebook' from 'origin'.
# Switched to a new branch 'fix/colab_notebook'

# %%
# %pip install -r "colab_requirements.txt"
# Out:
# Requirement already satisfied: kaggle<2.0.0,==1.8 in /usr/local/lib/python3.12/dist-packages (from -r colab_requirements.txt (line 1)) (1.8.0)
# Requirement already satisfied: kagglehub<2.0.0,==1.0.0 in /usr/local/lib/python3.12/dist-packages (from -r colab_requirements.txt (line 2)) (1.0.0)
# Requirement already satisfied: kagglesdk<1.0.0,==0.1.15 in /usr/local/lib/python3.12/dist-packages (from -r colab_requirements.txt (line 3)) (0.1.15)
# Requirement already satisfied: black>=24.10.0 in /usr/local/lib/python3.12/dist-packages (from kaggle<2.0.0,==1.8->-r colab_requirements.txt (line 1)) (26.3.1)
# Requirement already satisfied: bleach in /usr/local/lib/python3.12/dist-packages (from kaggle<2.0.0,==1.8->-r colab_requirements.txt (line 1)) (6.3.0)
# Requirement already satisfied: mypy>=1.15.0 in /usr/local/lib/python3.12/dist-packages (from kaggle<2.0.0,==1.8->-r colab_requirements.txt (line 1)) (1.19.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from kaggle<2.0.0,==1.8->-r colab_requirements.txt (line 1)) (5.29.6)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.12/dist-packages (from kaggle<2.0.0,==1.8->-r colab_requirements.txt (line 1)) (8.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kaggle<2.0.0,==1.8->-r colab_requirements.txt (line 1)) (2.32.4)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.12/dist-packages (from kaggle<2.0.0,==1.8->-r colab_requirements.txt (line 1)) (75.2.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.12/dist-packages (from kaggle<2.0.0,==1.8->-r colab_requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from kaggle<2.0.0,==1.8->-r colab_requirements.txt (line 1)) (4.67.3)
# Requirement already satisfied: types-requests in /usr/local/lib/python3.12/dist-packages (from kaggle<2.0.0,==1.8->-r colab_requirements.txt (line 1)) (2.32.4.20260107)
# Requirement already satisfied: types-tqdm in /usr/local/lib/python3.12/dist-packages (from kaggle<2.0.0,==1.8->-r colab_requirements.txt (line 1)) (4.67.3.20260303)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from kaggle<2.0.0,==1.8->-r colab_requirements.txt (line 1)) (2.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kagglehub<2.0.0,==1.0.0->-r colab_requirements.txt (line 2)) (26.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from kagglehub<2.0.0,==1.0.0->-r colab_requirements.txt (line 2)) (6.0.3)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from black>=24.10.0->kaggle<2.0.0,==1.8->-r colab_requirements.txt (line 1)) (8.3.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from black>=24.10.0->kaggle<2.0.0,==1.8->-r colab_requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: pathspec>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from black>=24.10.0->kaggle<2.0.0,==1.8->-r colab_requirements.txt (line 1)) (1.0.4)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.12/dist-packages (from black>=24.10.0->kaggle<2.0.0,==1.8->-r colab_requirements.txt (line 1)) (4.9.4)
# Requirement already satisfied: pytokens~=0.4.0 in /usr/local/lib/python3.12/dist-packages (from black>=24.10.0->kaggle<2.0.0,==1.8->-r colab_requirements.txt (line 1)) (0.4.1)
# Requirement already satisfied: typing_extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from mypy>=1.15.0->kaggle<2.0.0,==1.8->-r colab_requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: librt>=0.6.2 in /usr/local/lib/python3.12/dist-packages (from mypy>=1.15.0->kaggle<2.0.0,==1.8->-r colab_requirements.txt (line 1)) (0.8.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach->kaggle<2.0.0,==1.8->-r colab_requirements.txt (line 1)) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.12/dist-packages (from python-slugify->kaggle<2.0.0,==1.8->-r colab_requirements.txt (line 1)) (1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->kaggle<2.0.0,==1.8->-r colab_requirements.txt (line 1)) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->kaggle<2.0.0,==1.8->-r colab_requirements.txt (line 1)) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->kaggle<2.0.0,==1.8->-r colab_requirements.txt (line 1)) (2026.2.25)

# %%
from src.utils import set_seed

seed = 1238
set_seed(seed)

# %%
from src.preprocessing import build_image_path_label_df
from src.utils import get_list_of_img_paths

data_root = 'data'
data_df = build_image_path_label_df(data_root = data_root)
# plot dataset composition
data_df
# Out:
#                                  path  label
# 0        images/apple_pie/1005649.jpg      0
# 1        images/apple_pie/1011328.jpg      0
# 2         images/apple_pie/101251.jpg      0
# 3        images/apple_pie/1014775.jpg      0
# 4        images/apple_pie/1026328.jpg      0
# ...                               ...    ...
# 40995  images/french_fries/966854.jpg     40
# 40996  images/french_fries/973682.jpg     40
# 40997  images/french_fries/992636.jpg     40
# 40998  images/french_fries/999328.jpg     40
# 40999  images/french_fries/999957.jpg     40
#
# [41000 rows x 2 columns]

# %%
from src.preprocessing import split_dataset

csv_path = 'data'
train_df, eval_df, test_df = split_dataset(data_df, train_size = 0.7, test_size = 0.2, 
                                           val_size = 0.1, csv_path = 'data')
