# %%
from data.preprocessing import download_food101

path = download_food101()

# %%
from data.preprocessing import build_image_path_label_df

data_df = build_image_path_label_df(path)
data_df

# %%
from data.preprocessing import split_dataset

train_df, eval_df, test_df = split_dataset(data_df, train_perc = 0.7, test_perc = 0.2, eval_perc = 0.1)

# %%
from data.preprocessing import make_csv

train_csv = make_csv(csv_path = 'data', csv_name = 'train.csv')
test_csv = make_csv(csv_path = 'data', csv_name = 'train.csv')
teval_csv = make_csv(csv_path = 'data', csv_name = 'train.csv')
