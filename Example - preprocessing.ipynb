# %%
from google.colab import drive

drive.mount('/content/drive')
# %cd /content/drive/MyDrive
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive

# %%
import os

repo_path = "/content/drive/MyDrive/bitenet"

if os.path.isdir(repo_path):
    # %cd /content/drive/MyDrive/bitenet
    # !git fetch origin
    # !git reset --hard origin/fix/colab_notebook
else:
    # %cd /content/drive/MyDrive
    # !git clone -b fix/colab_notebook https://github.com/agataben/bitenet.git
    # %cd bitenet
# Out:
# /content/drive/MyDrive/bitenet
# Updating files: 100% (28719/28719), done.
# HEAD is now at b46da851 Add training notebook

# %%
# %pip install -r "colab_requirements.txt"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 kB 4.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.9/91.9 kB 11.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.3/256.3 kB 31.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.6/70.6 kB 10.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.4/160.4 kB 23.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 110.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 127.6 MB/s eta 0:00:0000:01:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 27.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.8/269.8 kB 31.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: kagglehub
#     Found existing installation: kagglehub 0.3.13
#     Uninstalling kagglehub-0.3.13:
# ...

# %%
from src.utils import set_seed

seed = 1238
set_seed(seed)

# %%
from src.preprocessing import build_image_path_label_df
from src.utils import get_list_of_img_paths

data_root = '/content/drive/MyDrive/bitenet/data'
data_df = build_image_path_label_df(data_root = data_root)
# plot dataset composition
data_df
# Out:
#                                  path  label
# 0        images/apple_pie/1005649.jpg      0
# 1        images/apple_pie/1011328.jpg      0
# 2         images/apple_pie/101251.jpg      0
# 3        images/apple_pie/1014775.jpg      0
# 4        images/apple_pie/1026328.jpg      0
# ...                               ...    ...
# 40995  images/french_fries/966854.jpg     40
# 40996  images/french_fries/973682.jpg     40
# 40997  images/french_fries/992636.jpg     40
# 40998  images/french_fries/999328.jpg     40
# 40999  images/french_fries/999957.jpg     40
#
# [41000 rows x 2 columns]

# %%
from src.preprocessing import split_dataset

csv_path = '/content/drive/MyDrive/bitenet/data'
train_df, val_df, test_df = split_dataset(data_df, train_size = 0.7, test_size = 0.2, 
                                           val_size = 0.1, csv_path = csv_path)

# %%
from src.utils import calculate_mean_and_std

csv_path = '/content/drive/MyDrive/bitenet/data/train.csv'
root = '/content/drive/MyDrive/bitenet/data'
yaml_path = '/content/drive/MyDrive/bitenet/data'
mean, std = calculate_mean_and_std(csv_path = csv_path, data_root = root, yaml_path = yaml_path)
print(mean)
print(std)
# Out:
# tensor([0.5407, 0.4469, 0.3528])
# tensor([0.2724, 0.2766, 0.2815])
