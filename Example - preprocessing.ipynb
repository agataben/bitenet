# %% [markdown]
# <a href="https://colab.research.google.com/github/agataben/bitenet/blob/main/Example%20-%20preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive
# !unzip -q images.zip -d /content/
# Out:
# /content/drive/MyDrive

# %%
my_os = 'macOS'
if  my_os == 'macOS':
  # %cd /content
  # !rm -r __MACOSX
# Out:
# /content

# %%
from os import path

# %cd /content
# !git clone https://github.com/agataben/bitenet.git
# %cd bitenet
# !git checkout main
# Out:
# /content
# Cloning into 'bitenet'...
# remote: Enumerating objects: 41500, done.
# remote: Counting objects: 100% (214/214), done.
# remote: Compressing objects: 100% (81/81), done.
# remote: Total 41500 (delta 161), reused 170 (delta 131), pack-reused 41286 (from 2)
# Receiving objects: 100% (41500/41500), 1.86 GiB | 41.23 MiB/s, done.
# Resolving deltas: 100% (270/270), done.
# /content/bitenet
# Already on 'main'
# Your branch is up to date with 'origin/main'.

# %%
from src.utils import set_seed

seed = 1238
set_seed(seed)

# %%
from src.preprocessing import build_image_path_label_df
from src.utils import get_list_of_img_paths

data_root = '/content'
data_df = build_image_path_label_df(data_root = data_root)
# plot dataset composition
data_df
# Out:
#                                    path  label
# 0           images/beignets/2192983.jpg      4
# 1           images/beignets/1557151.jpg      4
# 2           images/beignets/3531606.jpg      4
# 3             images/beignets/99712.jpg      4
# 4           images/beignets/2121224.jpg      4
# ...                                 ...    ...
# 26995  images/caprese_salad/2250280.jpg      8
# 26996  images/caprese_salad/1815512.jpg      8
# 26997  images/caprese_salad/1841490.jpg      8
# 26998  images/caprese_salad/3288824.jpg      8
# 26999  images/caprese_salad/1906754.jpg      8
#
# [27000 rows x 2 columns]

# %%
from src.preprocessing import split_dataset

csv_path = '/content'
train_df, val_df, test_df = split_dataset(data_df, train_size = 0.7, test_size = 0.2,
                                           val_size = 0.1, csv_path = csv_path)

# %%
from src.utils import calculate_mean_and_std

csv_path = '/content/train.csv'
data_root = '/content'
yaml_path = '/content'
mean, std = calculate_mean_and_std(csv_path = csv_path, data_root = data_root, yaml_path = yaml_path)
print(mean)
print(std)
# Out:
# tensor([0.5430, 0.4493, 0.3549])
# tensor([0.2716, 0.2769, 0.2829])

# %%
from google.colab import files

files.download('/content/train.csv')
files.download('/content/test.csv')
files.download('/content/val.csv')
files.download('/content/normalizzation.yaml')

# %%
# !mkdir /content/drive/MyDrive/data
# !cp /content/train.csv /content/drive/MyDrive/data/train.csv
# !cp /content/test.csv /content/drive/MyDrive/data/test.csv
# !cp /content/val.csv /content/drive/MyDrive/data/val.csv
# !cp /content/normalizzation.yaml /content/drive/MyDrive/data/normalizzation.yaml
