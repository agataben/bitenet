# %%
from google.colab import drive

drive.mount('/content/drive')
# %cd /content/drive/MyDrive
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive

# %%
# %cd /content/drive/MyDrive
# !unzip -q images.zip -d /content/
# Out:
# /content/drive/MyDrive

# %%
my_os = 'macOS'
if  my_os == 'macOS':
  # %cd /content
  # !rm -r __MACOSX
# Out:
# /content

# %%
# %cd /content
# !git clone https://github.com/agataben/bitenet.git
# %cd bitenet
# !git checkout main
# Out:
# /content
# Cloning into 'bitenet'...
# remote: Enumerating objects: 41506, done.
# remote: Counting objects: 100% (220/220), done.
# remote: Compressing objects: 100% (87/87), done.
# remote: Total 41506 (delta 164), reused 170 (delta 131), pack-reused 41286 (from 2)
# Receiving objects: 100% (41506/41506), 1.86 GiB | 71.72 MiB/s, done.
# Resolving deltas: 100% (273/273), done.
# /content/bitenet
# Already on 'main'
# Your branch is up to date with 'origin/main'.

# %%
from src.utils import set_seed

seed = 1238
set_seed(seed)

# %%
from src.utils import get_norm_parameters

yaml_path = '/content/drive/MyDrive/data'
mean, std = get_norm_parameters(yaml_path = yaml_path)
print(mean)
print(std)
# Out:
# tensor([0.5430, 0.4493, 0.3549])
# tensor([0.2716, 0.2769, 0.2829])

# %%
from torchvision import transforms

test_transf = transforms.Compose([ transforms.Resize(256),
                                  transforms.CenterCrop(224),
                                  transforms.ToTensor(),
                                  transforms.Normalize(mean,std)
                                ])

# %%
from src.food101_dataset import Food101DataSet

data_root = '/content'
test_csv = '/content/drive/MyDrive/data/test.csv'
test_ds = Food101DataSet(data_root = data_root, csv = test_csv, transform = test_transf)

# %%
from torch.utils.data import DataLoader

test_loader = DataLoader(test_ds, batch_size = 1024, num_workers = 2, shuffle = False)

# %%
import torch
from src.bitenet_v1 import BiteNetV1

ckpt_file_path = '/content/drive/MyDrive/results/bitenetv1/model/exp_1_1-19.pth'
ckpt_file = torch.load(ckpt_file_path)

model = BiteNetV1()
model.load_state_dict(ckpt_file['model'])
# Out:
# <All keys matched successfully>

# %%
import torch

print(torch.cuda.is_available())
# Out:
# True

# %%
from src.testing import test

predictions, labels = test(model, test_loader)
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# /tmp/ipykernel_507/1883016865.py in <cell line: 0>()
#       1 from src.testing import test
#       2
# ----> 3 predictions, labels = test(model, test_loader)
#
# /content/bitenet/src/testing.py in test(model, test_loader)
#      12     model.to(device)
#      13     predictions, labels = [], []
# ---> 14     for batch in test_loader:
#      15         x = batch[0].to(device)
#      16         y = batch[1].to(device)
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     739                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     740                 self._reset()  # type: ignore[call-arg]
# --> 741             data = self._next_data()
#     742             self._num_yielded += 1
#     743             if (
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1516                 worker_id, data = self._task_info.pop(self._rcvd_idx)
#    1517                 self._rcvd_idx += 1
# -> 1518                 return self._process_data(data, worker_id)
#    1519
#    1520             if self._shutdown or self._tasks_outstanding <= 0:
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in _process_data(self, data, worker_idx)
#    1584         self._try_put_index()
#    1585         if isinstance(data, ExceptionWrapper):
# -> 1586             data.reraise()
#    1587         return data
#    1588
#
# /usr/local/lib/python3.12/dist-packages/torch/_utils.py in reraise(self)
#     773             # be constructed, don't try to instantiate since we don't know how to
#     774             raise RuntimeError(msg) from None
# --> 775         raise exception
#     776
#     777
#
# UnidentifiedImageError: Caught UnidentifiedImageError in DataLoader worker process 1.
# Original Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/_utils/worker.py", line 358, in _worker_loop
#     data = fetcher.fetch(index)  # type: ignore[possibly-undefined]
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/_utils/fetch.py", line 54, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#             ~~~~~~~~~~~~^^^^^
#   File "/content/bitenet/src/food101_dataset.py", line 20, in __getitem__
#     img = Image.open(os.path.join(self.data_root, img_path)).convert('RGB')
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/PIL/Image.py", line 3580, in open
#     raise UnidentifiedImageError(msg)
# PIL.UnidentifiedImageError: cannot identify image file '/content/images/caprese_salad/1987239 (1).jpg'
