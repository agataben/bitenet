# %%
import os
import torch

from glob import glob
from src.utils import plot_dataset
from src.bitenet_v1 import BiteNetV1
from src.bitenet_v2 import BiteNetV2
from src.bitenet_v3 import BiteNetV3

# %%
dataset_path = 'data/samples'
class_to_indx_csv = 'data/classes.csv'
img_paths = glob(os.path.join(dataset_path, '*.jpg'))
plot_dataset(dataset_path, class_to_indx_csv)

# %%
bitenetv1 = BiteNetV1()

for path in img_paths:
  bitenetv1.predict(path)
# Out:
# cannoli
# escargots
# fish_and_chips
# club_sandwich
# donuts
# edamame
# baklava
# caesar_salad

# %%
bitenetv2 = BiteNetV2()

for path in img_paths:
  bitenetv2.predict(path)
# Out:
# cheesecake
# chicken_wings
# beignets
# club_sandwich
# cup_cakes
# edamame
# french_fries
# club_sandwich

# %%
bitenetv3 = BiteNetV3()

for path in img_paths:
  bitenetv3.predict(path)
# Out:
# cannoli
# baklava
# churros
# fish_and_chips
# cup_cakes
# edamame
# french_fries
# club_sandwich
