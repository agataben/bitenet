# %%
import os
import torch

from glob import glob
from src.bitenet_v3 import BiteNetV3
from src.utils import plot_dataset

# %%
image_path = 'data/samples/baklava.jpg'

model = BiteNetV3()
model.predict(image_path)
# Out:
# baklava
# tensor([1])
