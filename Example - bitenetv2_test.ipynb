# %%
from google.colab import drive

drive.mount('/content/drive')
# %cd /content/drive/MyDrive
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive

# %%
# %cd /content/drive/MyDrive
# !unzip -q images.zip -d /content/
# Out:
# /content/drive/MyDrive

# %%
my_os = 'macOS'
if  my_os == 'macOS':
  # %cd /content
  # !rm -r __MACOSX
# Out:
# /content

# %%
# %cd /content
# !git clone https://github.com/agataben/bitenet.git
# %cd bitenet
# !git checkout main
# Out:
# /content
# Cloning into 'bitenet'...
# remote: Enumerating objects: 41659, done.
# remote: Counting objects: 100% (172/172), done.
# remote: Compressing objects: 100% (59/59), done.
# remote: Total 41659 (delta 138), reused 123 (delta 113), pack-reused 41487 (from 2)
# Receiving objects: 100% (41659/41659), 1.87 GiB | 61.93 MiB/s, done.
# Resolving deltas: 100% (378/378), done.
# /content/bitenet
# Already on 'main'
# Your branch is up to date with 'origin/main'.

# %%
from src.utils import set_seed

seed = 1238
set_seed(seed)

# %%
import torch
from src.bitenet_v2 import BiteNetV2

ckpt_file_path = '/content/drive/MyDrive/results/bitenetv2/model/exp_2-20.pth'
ckpt_file = torch.load(ckpt_file_path)

model = BiteNetV2()
model.load_state_dict(ckpt_file['model'])
test_transf = model.weights.transforms()
# Out:
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
# 100%|██████████| 233M/233M [00:01<00:00, 157MB/s]

# %%
from src.food101_dataset import Food101DataSet

data_root = '/content'
test_csv = '/content/drive/MyDrive/data/test.csv'
test_ds = Food101DataSet(data_root = data_root, csv = test_csv, transform = test_transf)

# %%
from torch.utils.data import DataLoader

test_loader = DataLoader(test_ds, batch_size = 1024, num_workers = 2, shuffle = False)

# %%
import torch

print(torch.cuda.is_available())
# Out:
# True

# %%
from src.testing import test

predictions, labels = test(model, test_loader)
# Out:
# Accuracy: 0.5044444444444445
