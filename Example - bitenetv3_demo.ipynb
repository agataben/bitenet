# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content
# !git clone https://github.com/agataben/bitenet.git
# %cd bitenet
# !git checkout main
# Out:
# /content
# Cloning into 'bitenet'...
# remote: Enumerating objects: 41694, done.
# remote: Counting objects: 100% (207/207), done.
# remote: Compressing objects: 100% (86/86), done.
# remote: Total 41694 (delta 163), reused 144 (delta 121), pack-reused 41487 (from 2)
# Receiving objects: 100% (41694/41694), 1.87 GiB | 32.81 MiB/s, done.
# Resolving deltas: 100% (403/403), done.
# /content/bitenet
# Already on 'main'
# Your branch is up to date with 'origin/main'.

# %%
from src.utils import plot_dataset

dataset_path = '/content/drive/MyDrive/data/samples'
class_to_indx_csv = '/content/drive/MyDrive/data/classes.csv'
plot_dataset(dataset_path, class_to_indx_csv)

# %%
import torch
from src.bitenet_v3 import BiteNetV3

ckpt_file_path = '/content/drive/MyDrive/results/bitenetv3/model/exp_1-20.pth'
ckpt_file = torch.load(ckpt_file_path, map_location=torch.device('cpu'))
norm_params_file_path = '/content/drive/MyDrive/data'

model = BiteNetV3()
model.path_to_conversion_file = class_to_indx_csv
model.load_state_dict(ckpt_file['model'])
# Out:
# <All keys matched successfully>

# %%
import os
from glob import glob

img_paths = glob(os.path.join(dataset_path, '*.jpg'))
for path in img_paths:
  model.predict(path)
# Out:
# club_sandwich
# baklava
# edamame
# churros
# french_fries
# cannoli
# fish_and_chips
# cup_cakes
